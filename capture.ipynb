# %%
import cv2
from matplotlib import pyplot as plt
import datetime

# %%
# Connect to webcam (use index 2 for the third camera)
cap = cv2.VideoCapture(0, cv2.CAP_DSHOW)

# Get a frame from the capture device
ret, frame = cap.read()
frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
# Check if the frame was successfully captured
if ret:
    print("Frame captured successfully")
else:
    print("Failed to capture frame")

# Release the capture device
cap.release()
# Out:
# Frame captured successfully

# %%
plt.imshow(frame, cmap='gray')

# %%
# just randomly take photo
now = datetime.datetime.now()
date_time_str = now.strftime("%d%m%Y-%H%M")

def take_photo() :
 camera = cv2.VideoCapture(0, cv2.CAP_DSHOW)
 ret, frame = camera.read()
 cv2.imwrite(f"{date_time_str}.jpg", frame)
 camera.release()

# %%
take_photo()

# %%
# Render realtime
def realtime() :
 camera = cv2.VideoCapture(0, cv2.CAP_DSHOW)
 while camera.isOpened() :
  ret, frame = camera.read()
  cv2.imshow('Webcam', frame)

  # if 'q' is pressed, then quit
  if cv2.waitKey(1) & 0xFF == ord('q') :
   break
 camera.release()
 cv2.destroyAllWindows()

# %%
realtime()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 realtime()
#
# Cell In[6], line 6, in realtime()
#       4 while camera.isOpened() :
#       5  ret, frame = camera.read()
# ----> 6  cv2.imshow('Webcam', frame)
#       8  # if 'q' is pressed, then quit
#       9  if cv2.waitKey(1) & 0xFF == ord('q') :
#
# error: OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1272: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvShowImage'
